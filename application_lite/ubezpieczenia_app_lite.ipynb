# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import funkcje2016 as f


path = os.path.abspath("dane")
rate2016_df = pd.read_csv(os.path.join(path, "Rate2016.csv"))
network_df = pd.read_csv(os.path.join(path, "Network2016.csv"))
pa_df = pd.read_csv(os.path.join(path, "PlanAttributes2016.csv"))
bcs_df = pd.read_csv(os.path.join(path, "BenefitsCostSharing2016.csv"))
# Out:
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (7,10,11,12,32,33,34,40,41,42,149,151,152,153) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/joanna/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (3,6,9,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
f.best_healthcare(network_df, pa_df, rate2016_df, bcs_df)
# Out:
# Aplikacja służąca do wyboru ubezpieczenia zdrowotnego
#
# W pierwszym kroku zadamy Ci kilka pytań dotyczących Twoich preferencji odnośnie ubezpieczenia:
#
# Lista state codes:
# ['AK', 'AL', 'AR', 'AZ', 'DE', 'FL', 'GA', 'HI', 'IA', 'IL', 'IN', 'KS', 'LA', 'ME', 'MI', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM', 'NV', 'OH', 'OK', 'OR', 'PA', 'SC', 'SD', 'TN', 'TX', 'UT', 'VA', 'WI', 'WV', 'WY']
#
# Podaj kod stanu, w którym chcesz się ubezpieczyć:FL
# Czy chcesz się ubezpieczyć z rodziną? y/n:y
#
# Poniższa lista prezentuje dostępne opcje ubezpieczenia rodzinnego:
#
#  2 - Couple
#  3 - Primary Subscriber and One Dependent
#  4 - Primary Subscriber and Two Dependents
#  5 - Primary Subscriber and Three or More Dependents
#  6 - Couple And One Dependent
#  7 - Couple And Two Dependents
#  8 - Couple And Three or More Dependents
#
# Z powyższej listy wybierz numer opcji ubezpieczenia:3
#
# Poniżej znajdują się wybrane dla Ciebie plany ubezpieczeniowe:
#    PrimarySubscriberAndOneDependent          PlanId  \
# 0                              4.41  49193FL0280006
# 1                              7.35  49193FL0280003
# 2                             21.30  43274FL0030002
# 3                             45.66  93299FL0020002
#
#                                PlanMarketingName          NetworkName
# 0  Smile for Health - Certified High Option Plus   Advantage Plus 2.0
# 1       Smile for Health - Certified High Option   Advantage Plus 2.0
# 2                              EssentialSmile211   EssentialSmile EPO
# 3                           FL Affordable Smiles  FL Exchange Network
# W poniższych tabelach zaprezentowane zostały benefity, dla każdego z czterech powyższych planów
#        PlanIdBase                   BenefitName  \
# 0  49193FL0280006  Dental Check-Up for Children
# 1  49193FL0280006     Basic Dental Care - Child
# 2  49193FL0280006     Major Dental Care - Child
# 3  49193FL0280006             Accidental Dental
#
#                         ExtraCharge  LimitQty                        LimitUnit
# 0                         No Charge       2.0                 Exam(s) per Year
# 1  50% Coinsurance after deductible       1.0  Treatment(s) per Benefit Period
# 2  50% Coinsurance after deductible       1.0  Treatment(s) per Benefit Period
# 3                               20%       1.0  Treatment(s) per Benefit Period
#        PlanIdBase                   BenefitName  \
# 0  49193FL0280003  Dental Check-Up for Children
# 1  49193FL0280003     Basic Dental Care - Child
# 2  49193FL0280003     Major Dental Care - Child
# 3  49193FL0280003             Accidental Dental
#
#                         ExtraCharge  LimitQty                        LimitUnit
# 0                         No Charge       2.0                 Exam(s) per Year
# 1  50% Coinsurance after deductible       1.0  Treatment(s) per Benefit Period
# 2  50% Coinsurance after deductible       1.0  Treatment(s) per Benefit Period
# 3                               20%       1.0  Treatment(s) per Benefit Period
#        PlanIdBase                      BenefitName     ExtraCharge LimitQty  \
# 0  43274FL0030002  Routine Dental Services (Adult)  Not Applicable      N/A
# 1  43274FL0030002     Dental Check-Up for Children  Not Applicable        1
# 2  43274FL0030002        Basic Dental Care - Child  Not Applicable      N/A
# 3  43274FL0030002        Major Dental Care - Child  Not Applicable      N/A
# 4  43274FL0030002        Basic Dental Care - Adult  Not Applicable      N/A
#
#                LimitUnit
# 0                    N/A
# 1  Visit(s) per 6 Months
# 2                    N/A
# 3                    N/A
# 4                    N/A
#        PlanIdBase                      BenefitName     ExtraCharge LimitQty  \
# 0  93299FL0020002  Routine Dental Services (Adult)  Not Applicable      N/A
# 1  93299FL0020002     Dental Check-Up for Children  Not Applicable        1
# 2  93299FL0020002        Basic Dental Care - Child  Not Applicable      N/A
# 3  93299FL0020002        Major Dental Care - Child  Not Applicable      N/A
# 4  93299FL0020002        Basic Dental Care - Adult  Not Applicable        1
#
#                LimitUnit
# 0                    N/A
# 1  Visit(s) per 6 Months
# 2                    N/A
# 3                    N/A
# 4  Visit(s) per 6 Months
